# %%
import os
import rarfile # For handling .rar archives
from pymatgen.core import Structure
from pymatgen.io.vasp.inputs import Poscar # For parsing POSCAR content
from typing import List, Dict, Optional

# --- Definition of parse_single_poscar_content function (from previous response) ---
def parse_single_poscar_content(poscar_string_content: str, original_filename: str) -> Optional[Dict]:
    """
    Parses the string content of a single POSCAR file.
    Args:
        poscar_string_content (str): The string content of the POSCAR file.
        original_filename (str): The original filename (for context in messages).
    Returns:
        Optional[Dict]: A dictionary with parsed structure information or None if parsing fails.
    """
    try:
        if not poscar_string_content.strip():
            # print(f"Info: Content of '{original_filename}' is empty. Skipping.")
            return None
            
        poscar_obj = Poscar.from_string(poscar_string_content)
        structure = poscar_obj.structure

        return {
            "filename_in_archive": original_filename,
            "comment": poscar_obj.comment,
            "formula": structure.composition.reduced_formula,
            "natoms": len(structure),
            "lattice_vectors": structure.lattice.matrix.tolist(),
            "sites": [{"species": site.species_string,
                       "xyz_frac": site.frac_coords.tolist(),
                       "xyz_cart": site.coords.tolist()}
                      for site in structure.sites],
            "selective_dynamics": poscar_obj.selective_dynamics,
            "velocities": poscar_obj.velocities.tolist() if poscar_obj.velocities is not None else None,
            "pymatgen_structure": structure
        }
    except Exception as e:
        print(f"Error parsing content from '{original_filename}': {e}")
        return None

# --- Definition of process_rar_archive_for_poscars function (from previous response) ---
def process_rar_archive_for_poscars(archive_filepath: str, parse_only_first_poscar: bool = False) -> List[Dict]:
    """
    Extracts and parses POSCAR files from a .rar archive.
    Args:
        archive_filepath (str): Path to the .rar file.
        parse_only_first_poscar (bool): If True, stops after successfully parsing the first POSCAR found.
    Returns:
        List[Dict]: A list of dictionaries, each containing parsed data for one POSCAR.
    """
    parsed_structures_data = []
    
    if not os.path.exists(archive_filepath):
        print(f"Error: Archive file not found at '{archive_filepath}'")
        return parsed_structures_data

    try:
        with rarfile.RarFile(archive_filepath, 'r') as rf:
            print(f"Opened archive: '{archive_filepath}'. Contains {len(rf.namelist())} total entries.")
            
            processed_poscar_count = 0
            member_infos = rf.infolist() 

            for member_info in member_infos:
                filename_in_archive = member_info.filename
                
                if member_info.is_dir():
                    continue

                is_potential_poscar = (
                    "poscar" in filename_in_archive.lower() or
                    "contcar" in filename_in_archive.lower() or
                    filename_in_archive.lower().endswith(('.vasp', '.pos')) or
                    '.' not in os.path.basename(filename_in_archive) 
                )

                if not is_potential_poscar:
                    continue
                
                print(f"Attempting to extract and parse: '{filename_in_archive}'")
                
                try:
                    file_content_bytes = rf.read(member_info)
                    try:
                        file_content_string = file_content_bytes.decode('utf-8')
                    except UnicodeDecodeError:
                        file_content_string = file_content_bytes.decode('latin-1', errors='ignore')
                    
                    parsed_data = parse_single_poscar_content(file_content_string, filename_in_archive)
                    
                    if parsed_data:
                        parsed_structures_data.append(parsed_data)
                        processed_poscar_count += 1
                        if parse_only_first_poscar:
                            print(f"Successfully parsed the first POSCAR ('{filename_in_archive}'). Stopping as requested.")
                            return parsed_structures_data 
                            
                except Exception as e:
                    print(f"An unexpected error occurred while processing entry '{filename_in_archive}': {e}")

    except rarfile.NeedFirstVolume:
        print(f"Error: '{archive_filepath}' appears to be part of a multi-volume RAR archive.")
    except rarfile.BadRarFile:
        print(f"Error: '{archive_filepath}' is not a valid RAR file or is corrupted.")
    except Exception as e:
        print(f"Failed to open or process RAR archive '{archive_filepath}': {e}")
        print("Please ensure the 'unrar' utility is installed and accessible.")

    return parsed_structures_data


if __name__ == '__main__':
    # IMPORTANT: Replace this with the actual path to YOUR .rar file
    your_rar_file_path = "/Users/abiralshakya/Downloads/total_poscar_files.rar"

    if not os.path.exists(your_rar_file_path) or your_rar_file_path == "path/to/your/actual/file.rar":
        print(f"Please update the 'your_rar_file_path' variable in the script with the correct path to your .rar file.")
        # Create a dummy .rar for demonstration if the user hasn't set their path
        # This part is tricky as creating .rar programmatically is hard.
        # For now, we'll just print a message.
        print("Skipping execution as a valid .rar path is not provided.")
    else:
        print(f"--- Processing YOUR RAR file ('{your_rar_file_path}') to get ONLY THE FIRST POSCAR structure ---")
        
        # Call the function with parse_only_first_poscar=True
        first_structure_info_list = process_rar_archive_for_poscars(your_rar_file_path, parse_only_first_poscar=True)

        if first_structure_info_list: # This list should contain at most one item
            info = first_structure_info_list[0]
            print(f"\n--- Successfully Parsed First POSCAR From Your Archive ---")
            print(f"Original Filename in Archive: {info['filename_in_archive']}")
            print(f"Comment: {info['comment']}")
            print(f"Formula: {info['formula']}")
            print(f"Number of atoms: {info['natoms']}")
            print(f"Lattice Vectors (first vector): {info['lattice_vectors'][0]}")
            print(f"First site: {info['sites'][0]['species']} @ {info['sites'][0]['xyz_frac']}")
            if info.get('selective_dynamics'):
                print(f"Selective dynamics present for first atom (example): {info['selective_dynamics'][0] if info['selective_dynamics'] else 'N/A'}")
        elif len(first_structure_info_list) == 0:
            print("No POSCAR structures were successfully parsed from the archive, or the first attempted file was not a valid POSCAR.")
# Out:
# --- Processing YOUR RAR file ('/Users/abiralshakya/Downloads/total_poscar_files.rar') to get ONLY THE FIRST POSCAR structure ---
# Opened archive: '/Users/abiralshakya/Downloads/total_poscar_files.rar'. Contains 33808 total entries.
# Attempting to extract and parse: 'total_poscar_files/1.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/1.POSCAR': Failed the read enough data: req=2336 got=51
# Attempting to extract and parse: 'total_poscar_files/10000.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10000.POSCAR': Failed the read enough data: req=438 got=51
# Attempting to extract and parse: 'total_poscar_files/100001.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100001.POSCAR': Failed the read enough data: req=993 got=51
# Attempting to extract and parse: 'total_poscar_files/100002.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100002.POSCAR': Failed the read enough data: req=812 got=51
# Attempting to extract and parse: 'total_poscar_files/10001.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10001.POSCAR': Failed the read enough data: req=1239 got=51
# Attempting to extract and parse: 'total_poscar_files/100014.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100014.POSCAR': Failed the read enough data: req=2098 got=51
# Attempting to extract and parse: 'total_poscar_files/100015.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100015.POSCAR': Failed the read enough data: req=2090 got=51
# Attempting to extract and parse: 'total_poscar_files/100024.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100024.POSCAR': Failed the read enough data: req=751 got=51
# Attempting to extract and parse: 'total_poscar_files/100041.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100041.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/100045.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100045.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/100046.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100046.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/100047.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100047.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/100048.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100048.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/100049.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100049.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/100051.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100051.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/100052.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100052.POSCAR': Failed the read enough data: req=560 got=51
# Attempting to extract and parse: 'total_poscar_files/100053.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100053.POSCAR': Failed the read enough data: req=1176 got=51
# Attempting to extract and parse: 'total_poscar_files/100054.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100054.POSCAR': Failed the read enough data: req=2207 got=51
# Attempting to extract and parse: 'total_poscar_files/100060.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100060.POSCAR': Failed the read enough data: req=1727 got=51
# Attempting to extract and parse: 'total_poscar_files/100061.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100061.POSCAR': Failed the read enough data: req=934 got=51
# Attempting to extract and parse: 'total_poscar_files/100065.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100065.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/100069.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100069.POSCAR': Failed the read enough data: req=1604 got=51
# Attempting to extract and parse: 'total_poscar_files/100071.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100071.POSCAR': Failed the read enough data: req=2459 got=51
# Attempting to extract and parse: 'total_poscar_files/100074.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100074.POSCAR': Failed the read enough data: req=2465 got=51
# Attempting to extract and parse: 'total_poscar_files/100078.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100078.POSCAR': Failed the read enough data: req=3326 got=51
# Attempting to extract and parse: 'total_poscar_files/100080.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100080.POSCAR': Failed the read enough data: req=3312 got=51
# Attempting to extract and parse: 'total_poscar_files/100084.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100084.POSCAR': Failed the read enough data: req=1231 got=51
# Attempting to extract and parse: 'total_poscar_files/100088.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100088.POSCAR': Failed the read enough data: req=1719 got=51
# Attempting to extract and parse: 'total_poscar_files/100089.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100089.POSCAR': Failed the read enough data: req=2458 got=51
# Attempting to extract and parse: 'total_poscar_files/100090.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100090.POSCAR': Failed the read enough data: req=2458 got=51
# Attempting to extract and parse: 'total_poscar_files/100091.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100091.POSCAR': Failed the read enough data: req=629 got=51
# Attempting to extract and parse: 'total_poscar_files/100092.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100092.POSCAR': Failed the read enough data: req=629 got=51
# Attempting to extract and parse: 'total_poscar_files/100094.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100094.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/100098.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100098.POSCAR': Failed the read enough data: req=2031 got=51
# Attempting to extract and parse: 'total_poscar_files/100099.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100099.POSCAR': Failed the read enough data: req=2031 got=51
# Attempting to extract and parse: 'total_poscar_files/10010.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10010.POSCAR': Failed the read enough data: req=751 got=51
# Attempting to extract and parse: 'total_poscar_files/100110.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100110.POSCAR': Failed the read enough data: req=1109 got=51
# Attempting to extract and parse: 'total_poscar_files/100116.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100116.POSCAR': Failed the read enough data: req=2959 got=51
# Attempting to extract and parse: 'total_poscar_files/10012.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10012.POSCAR': Failed the read enough data: req=1360 got=51
# Attempting to extract and parse: 'total_poscar_files/100125.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100125.POSCAR': Failed the read enough data: req=1238 got=51
# Attempting to extract and parse: 'total_poscar_files/100127.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100127.POSCAR': Failed the read enough data: req=690 got=51
# Attempting to extract and parse: 'total_poscar_files/100130.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100130.POSCAR': Failed the read enough data: req=751 got=51
# Attempting to extract and parse: 'total_poscar_files/100131.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100131.POSCAR': Failed the read enough data: req=751 got=51
# Attempting to extract and parse: 'total_poscar_files/100149.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100149.POSCAR': Failed the read enough data: req=2207 got=51
# Attempting to extract and parse: 'total_poscar_files/10015.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10015.POSCAR': Failed the read enough data: req=1962 got=51
# Attempting to extract and parse: 'total_poscar_files/100150.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100150.POSCAR': Failed the read enough data: req=2708 got=51
# Attempting to extract and parse: 'total_poscar_files/100155.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100155.POSCAR': Failed the read enough data: req=1117 got=51
# Attempting to extract and parse: 'total_poscar_files/100161.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100161.POSCAR': Failed the read enough data: req=1360 got=51
# Attempting to extract and parse: 'total_poscar_files/100172.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100172.POSCAR': Failed the read enough data: req=1976 got=51
# Attempting to extract and parse: 'total_poscar_files/10018.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10018.POSCAR': Failed the read enough data: req=1481 got=51
# Attempting to extract and parse: 'total_poscar_files/100194.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100194.POSCAR': Failed the read enough data: req=1603 got=51
# Attempting to extract and parse: 'total_poscar_files/100203.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100203.POSCAR': Failed the read enough data: req=2343 got=51
# Attempting to extract and parse: 'total_poscar_files/10022.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10022.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/100229.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100229.POSCAR': Failed the read enough data: req=2458 got=51
# Attempting to extract and parse: 'total_poscar_files/100270.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100270.POSCAR': Failed the read enough data: req=567 got=51
# Attempting to extract and parse: 'total_poscar_files/100275.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100275.POSCAR': Failed the read enough data: req=1360 got=51
# Attempting to extract and parse: 'total_poscar_files/100277.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100277.POSCAR': Failed the read enough data: req=1970 got=51
# Attempting to extract and parse: 'total_poscar_files/100286.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100286.POSCAR': Failed the read enough data: req=1421 got=51
# Attempting to extract and parse: 'total_poscar_files/100287.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100287.POSCAR': Failed the read enough data: req=1421 got=51
# Attempting to extract and parse: 'total_poscar_files/100288.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100288.POSCAR': Failed the read enough data: req=2336 got=51
# Attempting to extract and parse: 'total_poscar_files/100293.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100293.POSCAR': Failed the read enough data: req=1231 got=51
# Attempting to extract and parse: 'total_poscar_files/100298.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100298.POSCAR': Failed the read enough data: req=688 got=51
# Attempting to extract and parse: 'total_poscar_files/100308.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100308.POSCAR': Failed the read enough data: req=2702 got=51
# Attempting to extract and parse: 'total_poscar_files/100313.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100313.POSCAR': Failed the read enough data: req=2214 got=51
# Attempting to extract and parse: 'total_poscar_files/10032.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10032.POSCAR': Failed the read enough data: req=1482 got=51
# Attempting to extract and parse: 'total_poscar_files/100320.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100320.POSCAR': Failed the read enough data: req=2229 got=51
# Attempting to extract and parse: 'total_poscar_files/100321.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100321.POSCAR': Failed the read enough data: req=1962 got=51
# Attempting to extract and parse: 'total_poscar_files/100322.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100322.POSCAR': Failed the read enough data: req=1963 got=51
# Attempting to extract and parse: 'total_poscar_files/100324.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100324.POSCAR': Failed the read enough data: req=993 got=51
# Attempting to extract and parse: 'total_poscar_files/100339.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100339.POSCAR': Failed the read enough data: req=3814 got=51
# Attempting to extract and parse: 'total_poscar_files/10034.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10034.POSCAR': Failed the read enough data: req=2214 got=51
# Attempting to extract and parse: 'total_poscar_files/100351.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100351.POSCAR': Failed the read enough data: req=1360 got=51
# Attempting to extract and parse: 'total_poscar_files/100354.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100354.POSCAR': Failed the read enough data: req=751 got=51
# Attempting to extract and parse: 'total_poscar_files/100355.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100355.POSCAR': Failed the read enough data: req=1055 got=51
# Attempting to extract and parse: 'total_poscar_files/100356.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100356.POSCAR': Failed the read enough data: req=3190 got=51
# Attempting to extract and parse: 'total_poscar_files/100357.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100357.POSCAR': Failed the read enough data: req=2458 got=51
# Attempting to extract and parse: 'total_poscar_files/100374.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100374.POSCAR': Failed the read enough data: req=1115 got=51
# Attempting to extract and parse: 'total_poscar_files/100389.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100389.POSCAR': Failed the read enough data: req=750 got=51
# Attempting to extract and parse: 'total_poscar_files/1004.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/1004.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/10040.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10040.POSCAR': Failed the read enough data: req=758 got=51
# Attempting to extract and parse: 'total_poscar_files/100403.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100403.POSCAR': Failed the read enough data: req=994 got=51
# Attempting to extract and parse: 'total_poscar_files/10041.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10041.POSCAR': Failed the read enough data: req=750 got=51
# Attempting to extract and parse: 'total_poscar_files/100416.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100416.POSCAR': Failed the read enough data: req=879 got=51
# Attempting to extract and parse: 'total_poscar_files/10043.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10043.POSCAR': Failed the read enough data: req=2459 got=51
# Attempting to extract and parse: 'total_poscar_files/100435.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100435.POSCAR': Failed the read enough data: req=1238 got=51
# Attempting to extract and parse: 'total_poscar_files/100437.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100437.POSCAR': Failed the read enough data: req=628 got=51
# Attempting to extract and parse: 'total_poscar_files/10044.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10044.POSCAR': Failed the read enough data: req=1116 got=51
# Attempting to extract and parse: 'total_poscar_files/100442.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100442.POSCAR': Failed the read enough data: req=1299 got=51
# Attempting to extract and parse: 'total_poscar_files/100451.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100451.POSCAR': Failed the read enough data: req=2214 got=51
# Attempting to extract and parse: 'total_poscar_files/100461.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100461.POSCAR': Failed the read enough data: req=1604 got=51
# Attempting to extract and parse: 'total_poscar_files/100465.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100465.POSCAR': Failed the read enough data: req=1230 got=51
# Attempting to extract and parse: 'total_poscar_files/100467.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100467.POSCAR': Failed the read enough data: req=750 got=51
# Attempting to extract and parse: 'total_poscar_files/100477.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100477.POSCAR': Failed the read enough data: req=2099 got=51
# Attempting to extract and parse: 'total_poscar_files/100492.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100492.POSCAR': Failed the read enough data: req=2526 got=51
# Attempting to extract and parse: 'total_poscar_files/10051.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10051.POSCAR': Failed the read enough data: req=560 got=51
# Attempting to extract and parse: 'total_poscar_files/100518.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100518.POSCAR': Failed the read enough data: req=1116 got=51
# Attempting to extract and parse: 'total_poscar_files/10052.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10052.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/100521.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100521.POSCAR': Failed the read enough data: req=1055 got=51
# Attempting to extract and parse: 'total_poscar_files/10053.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10053.POSCAR': Failed the read enough data: req=682 got=51
# Attempting to extract and parse: 'total_poscar_files/10054.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10054.POSCAR': Failed the read enough data: req=1298 got=51
# Attempting to extract and parse: 'total_poscar_files/10055.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10055.POSCAR': Failed the read enough data: req=1299 got=51
# Attempting to extract and parse: 'total_poscar_files/100566.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100566.POSCAR': Failed the read enough data: req=1108 got=51
# Attempting to extract and parse: 'total_poscar_files/100567.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100567.POSCAR': Failed the read enough data: req=986 got=51
# Attempting to extract and parse: 'total_poscar_files/100568.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100568.POSCAR': Failed the read enough data: req=986 got=51
# Attempting to extract and parse: 'total_poscar_files/10058.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10058.POSCAR': Failed the read enough data: req=1604 got=51
# Attempting to extract and parse: 'total_poscar_files/100583.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100583.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/100586.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100586.POSCAR': Failed the read enough data: req=568 got=51
# Attempting to extract and parse: 'total_poscar_files/10059.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10059.POSCAR': Failed the read enough data: req=1603 got=51
# Attempting to extract and parse: 'total_poscar_files/100594.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100594.POSCAR': Failed the read enough data: req=506 got=51
# Attempting to extract and parse: 'total_poscar_files/100596.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100596.POSCAR': Failed the read enough data: req=1053 got=51
# Attempting to extract and parse: 'total_poscar_files/100600.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100600.POSCAR': Failed the read enough data: req=1970 got=51
# Attempting to extract and parse: 'total_poscar_files/100603.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100603.POSCAR': Failed the read enough data: req=993 got=51
# Attempting to extract and parse: 'total_poscar_files/10061.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10061.POSCAR': Failed the read enough data: req=1603 got=51
# Attempting to extract and parse: 'total_poscar_files/100624.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100624.POSCAR': Failed the read enough data: req=1725 got=51
# Attempting to extract and parse: 'total_poscar_files/100625.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100625.POSCAR': Failed the read enough data: req=1725 got=51
# Attempting to extract and parse: 'total_poscar_files/100654.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100654.POSCAR': Failed the read enough data: req=987 got=51
# Attempting to extract and parse: 'total_poscar_files/10066.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10066.POSCAR': Failed the read enough data: req=2093 got=51
# Attempting to extract and parse: 'total_poscar_files/100661.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100661.POSCAR': Failed the read enough data: req=1726 got=51
# Attempting to extract and parse: 'total_poscar_files/100672.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100672.POSCAR': Failed the read enough data: req=498 got=51
# Attempting to extract and parse: 'total_poscar_files/100679.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100679.POSCAR': Failed the read enough data: req=871 got=51
# Attempting to extract and parse: 'total_poscar_files/100685.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100685.POSCAR': Failed the read enough data: req=2953 got=51
# Attempting to extract and parse: 'total_poscar_files/100688.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100688.POSCAR': Failed the read enough data: req=2519 got=51
# Attempting to extract and parse: 'total_poscar_files/100693.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100693.POSCAR': Failed the read enough data: req=1726 got=51
# Attempting to extract and parse: 'total_poscar_files/100695.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100695.POSCAR': Failed the read enough data: req=994 got=51
# Attempting to extract and parse: 'total_poscar_files/100703.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100703.POSCAR': Failed the read enough data: req=994 got=51
# Attempting to extract and parse: 'total_poscar_files/100704.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100704.POSCAR': Failed the read enough data: req=3190 got=51
# Attempting to extract and parse: 'total_poscar_files/100705.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100705.POSCAR': Failed the read enough data: req=995 got=51
# Attempting to extract and parse: 'total_poscar_files/100707.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100707.POSCAR': Failed the read enough data: req=3191 got=51
# Attempting to extract and parse: 'total_poscar_files/100710.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100710.POSCAR': Failed the read enough data: req=995 got=51
# Attempting to extract and parse: 'total_poscar_files/100711.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100711.POSCAR': Failed the read enough data: req=2708 got=51
# Attempting to extract and parse: 'total_poscar_files/100713.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100713.POSCAR': Failed the read enough data: req=2709 got=51
# Attempting to extract and parse: 'total_poscar_files/100733.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100733.POSCAR': Failed the read enough data: req=993 got=51
# Attempting to extract and parse: 'total_poscar_files/100737.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100737.POSCAR': Failed the read enough data: req=1971 got=51
# Attempting to extract and parse: 'total_poscar_files/100778.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100778.POSCAR': Failed the read enough data: req=1124 got=51
# Attempting to extract and parse: 'total_poscar_files/100780.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100780.POSCAR': Failed the read enough data: req=3679 got=51
# Attempting to extract and parse: 'total_poscar_files/100782.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100782.POSCAR': Failed the read enough data: req=1114 got=51
# Attempting to extract and parse: 'total_poscar_files/100787.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100787.POSCAR': Failed the read enough data: req=567 got=51
# Attempting to extract and parse: 'total_poscar_files/100789.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100789.POSCAR': Failed the read enough data: req=567 got=51
# Attempting to extract and parse: 'total_poscar_files/100790.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100790.POSCAR': Failed the read enough data: req=567 got=51
# Attempting to extract and parse: 'total_poscar_files/100791.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100791.POSCAR': Failed the read enough data: req=567 got=51
# Attempting to extract and parse: 'total_poscar_files/100796.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100796.POSCAR': Failed the read enough data: req=1116 got=51
# Attempting to extract and parse: 'total_poscar_files/10081.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10081.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/100815.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100815.POSCAR': Failed the read enough data: req=995 got=51
# Attempting to extract and parse: 'total_poscar_files/100816.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100816.POSCAR': Failed the read enough data: req=993 got=51
# Attempting to extract and parse: 'total_poscar_files/100817.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100817.POSCAR': Failed the read enough data: req=994 got=51
# Attempting to extract and parse: 'total_poscar_files/100818.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100818.POSCAR': Failed the read enough data: req=994 got=51
# Attempting to extract and parse: 'total_poscar_files/100827.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100827.POSCAR': Failed the read enough data: req=1482 got=51
# Attempting to extract and parse: 'total_poscar_files/100829.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100829.POSCAR': Failed the read enough data: req=1360 got=51
# Attempting to extract and parse: 'total_poscar_files/100830.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100830.POSCAR': Failed the read enough data: req=994 got=51
# Attempting to extract and parse: 'total_poscar_files/100834.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100834.POSCAR': Failed the read enough data: req=1177 got=51
# Attempting to extract and parse: 'total_poscar_files/100839.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100839.POSCAR': Failed the read enough data: req=1970 got=51
# Attempting to extract and parse: 'total_poscar_files/100849.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100849.POSCAR': Failed the read enough data: req=1238 got=51
# Attempting to extract and parse: 'total_poscar_files/100854.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100854.POSCAR': Failed the read enough data: req=2220 got=51
# Attempting to extract and parse: 'total_poscar_files/10086.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10086.POSCAR': Failed the read enough data: req=2458 got=51
# Attempting to extract and parse: 'total_poscar_files/100879.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100879.POSCAR': Failed the read enough data: req=994 got=51
# Attempting to extract and parse: 'total_poscar_files/100881.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/100881.POSCAR': Failed the read enough data: req=993 got=51
# Attempting to extract and parse: 'total_poscar_files/10096.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10096.POSCAR': Failed the read enough data: req=3318 got=51
# Attempting to extract and parse: 'total_poscar_files/101.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/101.POSCAR': Failed the read enough data: req=1618 got=51
# Attempting to extract and parse: 'total_poscar_files/1010.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/1010.POSCAR': Failed the read enough data: req=865 got=51
# Attempting to extract and parse: 'total_poscar_files/101011.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/101011.POSCAR': Failed the read enough data: req=1971 got=51
# Attempting to extract and parse: 'total_poscar_files/10104.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10104.POSCAR': Failed the read enough data: req=1177 got=51
# Attempting to extract and parse: 'total_poscar_files/10107.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10107.POSCAR': Failed the read enough data: req=3922 got=51
# Attempting to extract and parse: 'total_poscar_files/10108.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10108.POSCAR': Failed the read enough data: req=1970 got=51
# Attempting to extract and parse: 'total_poscar_files/10109.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10109.POSCAR': Failed the read enough data: req=1970 got=51
# Attempting to extract and parse: 'total_poscar_files/10125.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10125.POSCAR': Failed the read enough data: req=2206 got=51
# Attempting to extract and parse: 'total_poscar_files/10126.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10126.POSCAR': Failed the read enough data: req=628 got=51
# Attempting to extract and parse: 'total_poscar_files/10128.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10128.POSCAR': Failed the read enough data: req=2526 got=51
# Attempting to extract and parse: 'total_poscar_files/10129.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10129.POSCAR': Failed the read enough data: req=1483 got=51
# Attempting to extract and parse: 'total_poscar_files/10134.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10134.POSCAR': Failed the read enough data: req=1482 got=51
# Attempting to extract and parse: 'total_poscar_files/10136.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10136.POSCAR': Failed the read enough data: req=1361 got=51
# Attempting to extract and parse: 'total_poscar_files/10137.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10137.POSCAR': Failed the read enough data: req=1361 got=51
# Attempting to extract and parse: 'total_poscar_files/10142.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10142.POSCAR': Failed the read enough data: req=1482 got=51
# Attempting to extract and parse: 'total_poscar_files/10144.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10144.POSCAR': Failed the read enough data: req=1848 got=51
# Attempting to extract and parse: 'total_poscar_files/10147.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10147.POSCAR': Failed the read enough data: req=629 got=51
# Attempting to extract and parse: 'total_poscar_files/10151.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10151.POSCAR': Failed the read enough data: req=3442 got=51
# Attempting to extract and parse: 'total_poscar_files/10162.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10162.POSCAR': Failed the read enough data: req=2214 got=51
# Attempting to extract and parse: 'total_poscar_files/10173.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10173.POSCAR': Failed the read enough data: req=3182 got=51
# Attempting to extract and parse: 'total_poscar_files/10176.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10176.POSCAR': Failed the read enough data: req=2714 got=51
# Attempting to extract and parse: 'total_poscar_files/10179.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10179.POSCAR': Failed the read enough data: req=1253 got=51
# Attempting to extract and parse: 'total_poscar_files/10182.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10182.POSCAR': Failed the read enough data: req=2708 got=51
# Attempting to extract and parse: 'total_poscar_files/10184.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10184.POSCAR': Failed the read enough data: req=1483 got=51
# Attempting to extract and parse: 'total_poscar_files/10186.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10186.POSCAR': Failed the read enough data: req=1002 got=51
# Attempting to extract and parse: 'total_poscar_files/10187.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10187.POSCAR': Failed the read enough data: req=1732 got=51
# Attempting to extract and parse: 'total_poscar_files/102002.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102002.POSCAR': Failed the read enough data: req=1962 got=51
# Attempting to extract and parse: 'total_poscar_files/102005.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102005.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102015.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102015.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102016.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102016.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102020.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102020.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102021.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102021.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102022.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102022.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/102025.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102025.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102027.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102027.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/10203.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10203.POSCAR': Failed the read enough data: req=871 got=51
# Attempting to extract and parse: 'total_poscar_files/102032.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102032.POSCAR': Failed the read enough data: req=2634 got=51
# Attempting to extract and parse: 'total_poscar_files/102033.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102033.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102034.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102034.POSCAR': Failed the read enough data: req=751 got=51
# Attempting to extract and parse: 'total_poscar_files/102035.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102035.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/102038.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102038.POSCAR': Failed the read enough data: req=1719 got=51
# Attempting to extract and parse: 'total_poscar_files/10204.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10204.POSCAR': Failed the read enough data: req=3928 got=51
# Attempting to extract and parse: 'total_poscar_files/102048.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102048.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102049.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102049.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102057.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102057.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/10206.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10206.POSCAR': Failed the read enough data: req=873 got=51
# Attempting to extract and parse: 'total_poscar_files/102062.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102062.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102066.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102066.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102067.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102067.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102069.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102069.POSCAR': Failed the read enough data: req=438 got=51
# Attempting to extract and parse: 'total_poscar_files/102070.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102070.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102071.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102071.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102075.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102075.POSCAR': Failed the read enough data: req=1841 got=51
# Attempting to extract and parse: 'total_poscar_files/102076.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102076.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/102077.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102077.POSCAR': Failed the read enough data: req=438 got=51
# Attempting to extract and parse: 'total_poscar_files/102080.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102080.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102082.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102082.POSCAR': Failed the read enough data: req=498 got=51
# Attempting to extract and parse: 'total_poscar_files/102085.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102085.POSCAR': Failed the read enough data: req=498 got=51
# Attempting to extract and parse: 'total_poscar_files/102088.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102088.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/10209.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10209.POSCAR': Failed the read enough data: req=3441 got=51
# Attempting to extract and parse: 'total_poscar_files/102092.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102092.POSCAR': Failed the read enough data: req=560 got=51
# Attempting to extract and parse: 'total_poscar_files/102093.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102093.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/10210.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10210.POSCAR': Failed the read enough data: req=2945 got=51
# Attempting to extract and parse: 'total_poscar_files/102108.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102108.POSCAR': Failed the read enough data: req=690 got=51
# Attempting to extract and parse: 'total_poscar_files/102109.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102109.POSCAR': Failed the read enough data: req=934 got=51
# Attempting to extract and parse: 'total_poscar_files/102115.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102115.POSCAR': Failed the read enough data: req=1239 got=51
# Attempting to extract and parse: 'total_poscar_files/102128.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102128.POSCAR': Failed the read enough data: req=1963 got=51
# Attempting to extract and parse: 'total_poscar_files/102135.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102135.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102147.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102147.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/10217.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10217.POSCAR': Failed the read enough data: req=1612 got=51
# Attempting to extract and parse: 'total_poscar_files/102180.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102180.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102181.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102181.POSCAR': Failed the read enough data: req=438 got=51
# Attempting to extract and parse: 'total_poscar_files/102194.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102194.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102195.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102195.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102212.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102212.POSCAR': Failed the read enough data: req=751 got=51
# Attempting to extract and parse: 'total_poscar_files/102219.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102219.POSCAR': Failed the read enough data: req=2573 got=51
# Attempting to extract and parse: 'total_poscar_files/102241.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102241.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102255.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102255.POSCAR': Failed the read enough data: req=812 got=51
# Attempting to extract and parse: 'total_poscar_files/102257.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102257.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102258.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102258.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/102259.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102259.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102273.POSCAR'
# ...
# Attempting to extract and parse: 'total_poscar_files/102353.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102353.POSCAR': Failed the read enough data: req=2703 got=51
# Attempting to extract and parse: 'total_poscar_files/102359.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102359.POSCAR': Failed the read enough data: req=2703 got=51
# Attempting to extract and parse: 'total_poscar_files/102386.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102386.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102392.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102392.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/1024.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/1024.POSCAR': Failed the read enough data: req=1117 got=51
# Attempting to extract and parse: 'total_poscar_files/10240.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10240.POSCAR': Failed the read enough data: req=1490 got=51
# Attempting to extract and parse: 'total_poscar_files/10242.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10242.POSCAR': Failed the read enough data: req=994 got=51
# Attempting to extract and parse: 'total_poscar_files/10243.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10243.POSCAR': Failed the read enough data: req=2830 got=51
# Attempting to extract and parse: 'total_poscar_files/102433.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102433.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102441.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102441.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102443.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102443.POSCAR': Failed the read enough data: req=995 got=51
# Attempting to extract and parse: 'total_poscar_files/102444.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102444.POSCAR': Failed the read enough data: req=751 got=51
# Attempting to extract and parse: 'total_poscar_files/10245.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10245.POSCAR': Failed the read enough data: req=1733 got=51
# Attempting to extract and parse: 'total_poscar_files/102451.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102451.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102458.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102458.POSCAR': Failed the read enough data: req=1360 got=51
# Attempting to extract and parse: 'total_poscar_files/102465.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102465.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102469.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102469.POSCAR': Failed the read enough data: req=1414 got=51
# Attempting to extract and parse: 'total_poscar_files/10247.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10247.POSCAR': Failed the read enough data: req=1726 got=51
# Attempting to extract and parse: 'total_poscar_files/102480.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102480.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102481.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102481.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102483.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102483.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/10249.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10249.POSCAR': Failed the read enough data: req=3678 got=51
# Attempting to extract and parse: 'total_poscar_files/102490.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102490.POSCAR': Failed the read enough data: req=1604 got=51
# Attempting to extract and parse: 'total_poscar_files/102492.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102492.POSCAR': Failed the read enough data: req=690 got=51
# Attempting to extract and parse: 'total_poscar_files/1025.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/1025.POSCAR': Failed the read enough data: req=2946 got=51
# Attempting to extract and parse: 'total_poscar_files/10250.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10250.POSCAR': Failed the read enough data: req=2702 got=51
# Attempting to extract and parse: 'total_poscar_files/102511.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102511.POSCAR': Failed the read enough data: req=865 got=51
# Attempting to extract and parse: 'total_poscar_files/102513.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102513.POSCAR': Failed the read enough data: req=1963 got=51
# Attempting to extract and parse: 'total_poscar_files/102517.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102517.POSCAR': Failed the read enough data: req=995 got=51
# Attempting to extract and parse: 'total_poscar_files/102560.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102560.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/10257.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10257.POSCAR': Failed the read enough data: req=1237 got=51
# Attempting to extract and parse: 'total_poscar_files/102605.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102605.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102624.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102624.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/102629.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102629.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102642.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102642.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102643.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102643.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102646.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102646.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102653.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102653.POSCAR': Failed the read enough data: req=1963 got=51
# Attempting to extract and parse: 'total_poscar_files/102656.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102656.POSCAR': Failed the read enough data: req=308 got=51
# Attempting to extract and parse: 'total_poscar_files/102657.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102657.POSCAR': Failed the read enough data: req=491 got=51
# Attempting to extract and parse: 'total_poscar_files/102659.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102659.POSCAR': Failed the read enough data: req=369 got=51
# Attempting to extract and parse: 'total_poscar_files/102689.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102689.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/1027.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/1027.POSCAR': Failed the read enough data: req=697 got=51
# Attempting to extract and parse: 'total_poscar_files/102705.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102705.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102706.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102706.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102707.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102707.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102711.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102711.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102718.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102718.POSCAR': Failed the read enough data: req=1718 got=51
# Attempting to extract and parse: 'total_poscar_files/102722.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102722.POSCAR': Failed the read enough data: req=742 got=51
# Attempting to extract and parse: 'total_poscar_files/102724.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102724.POSCAR': Failed the read enough data: req=1047 got=51
# Attempting to extract and parse: 'total_poscar_files/102736.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102736.POSCAR': Failed the read enough data: req=1109 got=51
# Attempting to extract and parse: 'total_poscar_files/102737.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102737.POSCAR': Failed the read enough data: req=377 got=51
# Attempting to extract and parse: 'total_poscar_files/102741.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102741.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102755.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102755.POSCAR': Failed the read enough data: req=507 got=51
# Attempting to extract and parse: 'total_poscar_files/102779.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102779.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102798.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102798.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/1028.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/1028.POSCAR': Failed the read enough data: req=697 got=51
# Attempting to extract and parse: 'total_poscar_files/102802.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102802.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102803.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102803.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102804.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102804.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102805.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102805.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102811.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102811.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102816.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102816.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102829.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102829.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/10283.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/10283.POSCAR': Failed the read enough data: req=567 got=51
# Attempting to extract and parse: 'total_poscar_files/102834.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102834.POSCAR': Failed the read enough data: req=499 got=51
# Attempting to extract and parse: 'total_poscar_files/102837.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102837.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102843.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102843.POSCAR': Failed the read enough data: req=743 got=51
# Attempting to extract and parse: 'total_poscar_files/102851.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102851.POSCAR': Failed the read enough data: req=621 got=51
# Attempting to extract and parse: 'total_poscar_files/102863.POSCAR'
# An unexpected error occurred while processing entry 'total_poscar_files/102863.POSCAR': Failed the read enough data: req=987 got=51
# Attempting to extract and parse: 'total_poscar_files/102864.POSCAR'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 128
#     125 print(f"--- Processing YOUR RAR file ('{your_rar_file_path}') to get ONLY THE FIRST POSCAR structure ---")
#     127 # Call the function with parse_only_first_poscar=True
# --> 128 first_structure_info_list = process_rar_archive_for_poscars(your_rar_file_path, parse_only_first_poscar=True)
#     130 if first_structure_info_list: # This list should contain at most one item
#     131     info = first_structure_info_list[0]
#
# Cell In[3], line 85, in process_rar_archive_for_poscars(archive_filepath, parse_only_first_poscar)
#      82 print(f"Attempting to extract and parse: '{filename_in_archive}'")
#      84 try:
# ---> 85     file_content_bytes = rf.read(member_info)
#      86     try:
#      87         file_content_string = file_content_bytes.decode('utf-8')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/rarfile.py:838, in RarFile.read(self, name, pwd)
#     825 """Return uncompressed data for archive entry.
#     826
#     827 For longer files using :meth:`~RarFile.open` may be better idea.
#    (...)
#     834         password to use for extracting.
#     835 """
#     837 with self.open(name, "r", pwd) as f:
# --> 838     return f.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/rarfile.py:2296, in RarExtFile.read(self, n)
#    2293 orig = n
#    2294 while n > 0:
#    2295     # actual read
# -> 2296     data = self._read(n)
#    2297     if not data:
#    2298         break
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/rarfile.py:2461, in PipeReader._read(self, cnt)
#    2458 """Read from pipe."""
#    2460 # normal read is usually enough
# -> 2461 data = self._fd.read(cnt)
#    2462 if len(data) == cnt or not data:
#    2463     return data
#
# KeyboardInterrupt:
